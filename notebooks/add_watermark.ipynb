# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import watermark.config as config

from PIL import Image
from watermark.watermark import RectangleWatermark, TextWatermark, LogoWatermark

# %%
images = [Image.open(path).convert("RGBA") for path in config.paths.EXTERNAL.glob("*")]
logo_paths = list(config.paths.LOGOS.glob("*"))

# %%
text_watermark=TextWatermark("Asia",5,125,randomize=True)
adidas_watermark=LogoWatermark(logo_path=logo_paths[0], percentage_size=20,intensity=125,randomize=True)
rectangle_watermark=RectangleWatermark(25,25,25,25,125,randomize=True)
digitalcloud_watermark=LogoWatermark(logo_path=config.paths.LOGOS/"digitalcloud.png", percentage_size=20,intensity=125,randomize=True)

# %%
rectangle_watermark.add_to_image(image=images[0])
# Out:
# <PIL.Image.Image image mode=RGBA size=275x183>

# %%
adidas_watermark.add_to_image(image=images[0])
# Out:
# <PIL.Image.Image image mode=RGBA size=275x183>

# %%
text_watermark.add_to_image(image=images[0])
# Out:
# <PIL.Image.Image image mode=RGBA size=275x183>

# %%
digitalcloud_watermark.add_to_image(image=images[0])
# Out:
# <PIL.Image.Image image mode=RGBA size=275x183>
