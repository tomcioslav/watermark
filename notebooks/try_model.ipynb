# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import watermark
import watermark.examples as ex
from torch.utils.data import DataLoader
from torchvision.transforms import ToPILImage

# %%
val_dataloader = ex.full_logo_val_dataloader

# %%
sample_input, sample_target = next(iter(val_dataloader))

# %%
unet = watermark.UNet()

# %%
sample_output = unet(sample_input)

# %%
ToPILImage()(sample_input[0])
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
ToPILImage()(sample_output[0])
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>
